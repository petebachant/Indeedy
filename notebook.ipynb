# %% [markdown]
# Using Indeedy
# =============
# This notebook uses Indeedy to count the number of job postings for various keywords on Indeed.com.

# %%
# %matplotlib inline
import indeedy

# Variables to consider
cad = ["SolidWorks",
       "Catia",
       "Pro/ENGINEER",
       "Creo",
       "Unigraphics",
       "NX",
       "Inventor"]
language = ["Python",
            "C",
            "Java",
            "MATLAB",
            "LabVIEW",
            "FORTRAN"]
degree = ["BS",
          "MS",
          "PhD"]
cfd = ["OpenFOAM",
       "Fluent",
       "COMSOL",
       "SolidWorks Flow Simulation"]
welding = ["MIG",
           "TIG",
           "stick"]

njobs, salaries = indeedy.compare_jobs_title(cad, constant="mechanical engineer",
                                             location="")

# %%
indeedy.dual_bar_graph(cad, njobs, salaries)
